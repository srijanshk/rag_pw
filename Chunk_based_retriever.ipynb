# %%
import os
os.environ.setdefault("CUDA_VISIBLE_DEVICES", "3")
from BGERetriever_v3 import BGERetriever
from FlagEmbedding import BGEM3FlagModel

# %%
model = BGEM3FlagModel("BAAI/bge-m3", use_fp16=True, device="cuda", normalize_embeddings=True)
# Out:
# Fetching 30 files:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
retriever = BGERetriever(
    embedding_model=model,
    index_path="/local00/student/shakya/bge_m3_faiss.index",
    metadata_path="/local00/student/shakya/chunk_metadata.jsonl",             # ✅ use JSONL with text
    example_map_path="data/openmathinstruct2/example_id_to_data.json",        # same as before
    nprobe=64,
    use_all_gpus=True,
    chunk_texts_path="/local00/student/shakya/chunk_texts.json",              # ✅ optional but helps reranker
)
# Out:
# Loading FAISS index from /local00/student/shakya/bge_m3_faiss.index
# Set IVF nprobe = 64
# Index dimension: 1024
# Index total vectors: 13972791
# Loading chunk metadata from /local00/student/shakya/chunk_metadata.jsonl
# Detected JSONL; loaded 13972791 entries
# Loaded 13972791 chunk texts from /local00/student/shakya/chunk_texts.json
# Loading example map from data/openmathinstruct2/example_id_to_data.json
# Loaded 13972791 full examples

# %%
print(retriever.get_stats())
# Out:
# {'num_documents': 13972791, 'num_examples': 13972791, 'index_dimension': 1024, 'index_total_vectors': 13972791, 'device': 'cuda'}

# %%
q = "Formula for calculating new value after a percentage increase"

# %%
hits = retriever.search_and_rerank(q, top_k=200, top_k_final=10)
# Out:
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.42it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.74s/it]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.76it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.03it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.54it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.40it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.48it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.34it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.43it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.48it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.50it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.48it/s]

# %%
for i, r in enumerate(hits, 1):
    print(f"\n=== Reranked {i} ===")
    print("Score:", r.get("rerank_score", r["dense_score"]))
    print("Chunk ID:", r["chunk_id"])
    print("Full Problem:", (r["full_problem"] or r["problem"])[:250])
    print("Full Solution:", (r["full_solution"] or r["solution_chunk"])[:300], "...")
# Out:
# === Reranked 1 ===
# Score: 0.7856127023696899
# Chunk ID: 7546008_0
# Full Problem: The value of a share increased from $120 to $150 in one month. What was the percentage increase in the value of the share?
# Full Solution: The formula for percentage increase is $\left( \frac{\text{new value} - \text{old value}}{\text{old value}} \right) \times 100$.
#
# In this case, the old value is $120 and the new value is $150.
#
# Plugging these values into the formula:
# \[ \left( \frac{150 - 120}{120} \right) \times 100 = \left( \frac{ ...
#
# === Reranked 2 ===
# Score: 0.7711079120635986
# Chunk ID: 9891553_0
# Full Problem: The value of a share increased from $120 to $150 in one month. What was the percentage increase in the value of the share?
# Full Solution: To find the percentage increase, first find the difference in value:
# \[ \text{Increase} = \text{New Value} - \text{Old Value} = 150 - 120 = 30 \]
#
# Then, calculate the percentage increase using the formula:
# \[ \text{Percentage Increase} = \left( \frac{\text{Increase}}{\text{Old Value}} \right) \times ...
#
# === Reranked 3 ===
# Score: 0.7677526473999023
# Chunk ID: 13108907_0
# Full Problem: A manager has set a goal to increase the sales of his company by a certain percentage each year. If the company's sales were $50,000 last year, what percentage increase is needed this year to reach a total of $110,000 in sales?
# Full Solution: To find the percentage increase needed, we can use the formula:
# \[ \text{Percentage Increase} = \frac{\text{New Value} - \text{Old Value}}{\text{Old Value}} \times 100 \]
#
# Here, the old value is $50,000, and the new value is $110,000.
#
# \[ \text{Percentage Increase} = \frac{110,000 - 50,000}{50,000}  ...
#
# === Reranked 4 ===
# Score: 0.7666950821876526
# Chunk ID: 677334_0
# Full Problem: A manager has set a goal to increase the sales of his company by a certain percentage each year. If the company's sales were $50,000 last year, what percentage increase is needed this year to reach a total of $110,000 in sales?
# Full Solution: Let $x$ be the percentage increase needed.
#
# The formula to calculate the new sales after a percentage increase is:
# \[ \text{New Sales} = \text{Old Sales} + (\text{Old Sales} \times \text{Percentage Increase}) \]
#
# Given that the old sales were $50,000 and the target new sales are $110,000, we can set ...
#
# === Reranked 5 ===
# Score: 0.7666457891464233
# Chunk ID: 4187333_0
# Full Problem: A manager has set a goal to increase the sales of his company by a certain percentage each year. If the company's sales were $50,000 last year, what percentage increase is needed this year to reach a total of $110,000 in sales?
# Full Solution: Let's use the following formula to find the percentage increase:
# \[ \text{Percentage increase} = \left( \frac{\text{New value} - \text{Old value}}{\text{Old value}} \right) \times 100 \]
#
# In this case, the old value is $50,000 and the new value is $110,000.
#
# Substitute the values into the formula:
# \ ...
#
# === Reranked 6 ===
# Score: 0.7648796439170837
# Chunk ID: 2573755_0
# Full Problem: A manager has set a goal to increase the sales of his company by a certain percentage each year. If the company's sales were $50,000 last year, what percentage increase is needed this year to reach a total of $110,000 in sales?
# Full Solution: To find the percentage increase needed, we can use the formula:
# \[ \text{Percentage Increase} = \left( \frac{\text{New Value} - \text{Old Value}}{\text{Old Value}} \right) \times 100 \]
#
# Here, the old value is $50,000, and the new value is $110,000.
#
# \[ \text{Percentage Increase} = \left( \frac{110, ...
#
# === Reranked 7 ===
# Score: 0.7639581561088562
# Chunk ID: 1765240_0
# Full Problem: The value of a share increased from $120 to $150 in one month. What was the percentage increase in the value of the share?
# Full Solution: To find the percentage increase in the value of the share, use the formula:
# \[ \text{Percentage Increase} = \left( \frac{\text{Increase in Value}}{\text{Original Value}} \right) \times 100 \]
#
# Given that the original value of the share is $120 and the new value is $150, the increase in value is:
# \[  ...
#
# === Reranked 8 ===
# Score: 0.7628389596939087
# Chunk ID: 1915499_0
# Full Problem: The value of a share increased from $120 to $150 in one month. What was the percentage increase in the value of the share?
# Full Solution: To find the percentage increase, we can use the formula:
#
# Percentage increase = (New value - Old value) / Old value * 100
#
# Substituting the values, we get:
#
# Percentage increase = (150 - 120) / 120 * 100
# = 30 / 120 * 100
# = 0.25 * 100
# = 25%
#
# So, the percentage increase in the value of the share is $\b ...
#
# === Reranked 9 ===
# Score: 0.7617214322090149
# Chunk ID: 7881241_0
# Full Problem: A manager has set a goal to increase the sales of his company by a certain percentage each year. If the company's sales were $50,000 last year, what percentage increase is needed this year to reach a total of $110,000 in sales?
# Full Solution: To find the percentage increase, we can use the formula:
# \[ \text{Percentage increase} = \left( \frac{\text{New amount} - \text{Old amount}}{\text{Old amount}} \right) \times 100 \]
#
# In this case, the old amount is $50,000 and the new amount is $110,000.
#
# \[ \text{Percentage increase} = \left( \frac ...
#
# === Reranked 10 ===
# Score: 0.7606662511825562
# Chunk ID: 6827578_0
# Full Problem: The value of a share increased from $120 to $150 in one month. What was the percentage increase in the value of the share?
# Full Solution: To find the percentage increase, we use the formula:
# \[ \text{Percentage increase} = \frac{\text{Increase in value}}{\text{Original value}} \times 100\% \]
#
# Given that the original value is $120 and the new value is $150, the increase in value is $150 - $120 = $30.
#
# Substitute the values into the fo ...

# %%
import json
from pathlib import Path

# %%
CHUNK_JSONL = "./data/openmathinstruct2/openmath_chunks.jsonl"
OUT_META_JSONL = "/local00/student/shakya/chunk_metadata.jsonl"
OUT_TEXTS_JSON = "/local00/student/shakya/chunk_texts.json"

# %%
def main():
    texts = []
    n = 0
    with open(CHUNK_JSONL, "r", encoding="utf-8") as fin, \
         open(OUT_META_JSONL, "w", encoding="utf-8") as fmeta:
        for i, line in enumerate(fin):
            o = json.loads(line)
            # Expect structure produced by your chunker: {"chunk_id": "<eid>_<j>", "example_id": <eid>, "text": "..."}
            chunk_id = o.get("chunk_id", "")
            row_id = o.get("example_id", None)
            text = o.get("text", "")

            # Write metadata JSONL (one object per FAISS vector id)
            meta_obj = {
                "id": i,                     # FAISS vector id
                "chunk_id": chunk_id,
                "row_id": str(row_id) if row_id is not None else "",
                "text": text,
                # optional placeholders if you want the schema consistent
                "problem": "",
                "solution_chunk": "",
                "expected_answer": "",
                "problem_from": "",
            }
            fmeta.write(json.dumps(meta_obj) + "\n")
            texts.append(text)
            n += 1

    with open(OUT_TEXTS_JSON, "w", encoding="utf-8") as ftxt:
        json.dump(texts, ftxt)

    print(f"✅ Wrote {n} metadata rows to {OUT_META_JSONL}")
    print(f"✅ Wrote {len(texts)} texts to {OUT_TEXTS_JSON}")

# %%
main()
# Out:
# ✅ Wrote 13972791 metadata rows to /local00/student/shakya/chunk_metadata.jsonl
# ✅ Wrote 13972791 texts to /local00/student/shakya/chunk_texts.json

# %%
new_question = "The Fundamental Theorem of Arithmetic"
hits = retriever.search_and_rerank(new_question, top_k=200, top_k_final=10)
# Out:
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.70it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.91it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.74it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.11it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.18it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.15it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.18it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.17it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.33it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.24it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.28it/s]
# Compute Scores: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.96it/s]

# %%
for i, r in enumerate(hits, 1):
    print(f"\n=== Reranked {i} ===")
    print("Score:", r.get("rerank_score", r["dense_score"]))
    print("Chunk ID:", r["chunk_id"])
    print("Full Problem:", (r["full_problem"] or r["problem"])[:250])
    print("Full Solution:", (r["full_solution"] or r["solution_chunk"])[:300], "...")
# Out:
# === Reranked 1 ===
# Score: 0.5531953573226929
# Chunk ID: 7429448_0
# Full Problem: Consider a sequence of angles
# $$\arctan (\tan \alpha), \ \arctan (\tan 2 \alpha), \ \arctan (\tan 3 \alpha), \ \arctan (\tan t \alpha).$$
# Find the least positive value of $t$ such that this sequence forms an arithmetic progression for some $\alpha$ w
# Full Solution: To form an arithmetic progression, the difference between consecutive terms must be constant.
#
# For the given sequence of angles, the terms are:
# \[ \arctan (\tan \alpha), \ \arctan (\tan 2 \alpha), \ \arctan (\tan 3 \alpha), \ \arctan (\tan t \alpha) \]
#
# The difference between the first and second te ...
#
# === Reranked 2 ===
# Score: 0.5513421893119812
# Chunk ID: 2892983_0
# Full Problem: Let
# \[\begin{array}{ll}
# \mbox{$A=\{a_1, a_2, \cdots, a_n\}$}&\mbox{ and}\\
# \mbox{$B=\{b_1, b_2, \cdots, b_n\}$}&
# \end{array}\]
# be two different subsets of the set of natural numbers, such that the arithmetic mean of all elements of $B$ is greater tha
# Full Solution: ## Step 1: Define the arithmetic mean, quadratic mean, and the difference between the greatest and least elements for both sets.
# Let's denote the arithmetic mean of set A as $\mu_A = \frac{1}{n} \sum_{i=1}^{n} a_i$ and the arithmetic mean of set B as $\mu_B = \frac{1}{n} \sum_{i=1}^{n} b_i$. The qua ...
#
# === Reranked 3 ===
# Score: 0.5508465766906738
# Chunk ID: 9735409_0
# Full Problem: Let $\alpha$ be a fixed real number between $0$ and $\frac{\pi}{2}$. Let $m$ be a positive integer. For any real number $t$, define $f(t)=\arctan (\tan (t\alpha))$. Find the smallest positive real number $k$ such that the sequence
#
# \[f(1), f(2), f(3)
# Full Solution: The function $f(t)$ is periodic with period $\frac{\pi}{\alpha}$. Therefore, the sequence $f(1), f(2), f(3), f(k)$ will be an arithmetic progression if and only if $f(k) - f(3) = f(3) - f(2) = f(2) - f(1)$.
#
# Since $f(t)$ is periodic with period $\frac{\pi}{\alpha}$, we can write $f(t) = f(t - \frac{ ...
#
# === Reranked 4 ===
# Score: 0.547336220741272
# Chunk ID: 13405355_0
# Full Problem: Let
# \[\begin{array}{ll}
# \mbox{$A=\{a_1, a_2, \cdots, a_n\}$}&\mbox{ and}\\
# \mbox{$B=\{b_1, b_2, \cdots, b_n\}$}&
# \end{array}\]
# be two different subsets of the set of natural numbers, such that the arithmetic mean of all elements of $B$ is greater tha
# Full Solution: ## Step 1: Define the arithmetic mean, quadratic mean, and the difference between the greatest and least element for both sets.
# The arithmetic mean of set $A$ is $\frac{1}{n} \sum_{i=1}^{n} a_i$ and of set $B$ is $\frac{1}{n} \sum_{i=1}^{n} b_i$. The quadratic mean of set $A$ is $\sqrt{\frac{1}{n} \ ...
#
# === Reranked 5 ===
# Score: 0.5433698892593384
# Chunk ID: 10407357_0
# Full Problem: Find the smallest positive value of $t$ such that
# \[\arctan (\tan \beta), \ \arctan (\tan 3 \beta), \ \arctan (\tan 8 \beta), \ \arctan (\tan t \beta)\] forms an arithmetic progression for some $\beta$ with $0 < \beta < \frac{\pi}{4}$.
# Full Solution: ## Step 1: Recall the definition of an arithmetic progression
# An arithmetic progression is a sequence of numbers where the difference between any two consecutive terms is constant.
#
# ## Step 2: Apply the definition of an arithmetic progression to the given sequence
# For the given sequence to form an a ...
#
# === Reranked 6 ===
# Score: 0.542435884475708
# Chunk ID: 1564743_0
# Full Problem: Let
# \[\begin{array}{ll}
# \mbox{$A=\{a_1, a_2, \cdots, a_n\}$}&\mbox{ and}\\
# \mbox{$B=\{b_1, b_2, \cdots, b_n\}$}&
# \end{array}\]
# be two different subsets of the set of natural numbers, such that the arithmetic mean of all elements of $B$ is greater tha
# Full Solution: ## Step 1: Define the arithmetic mean, quadratic mean, and the difference between the greatest and least elements for both sets.
# Let's denote the arithmetic mean of set $A$ as $\mu_A = \frac{1}{n} \sum_{i=1}^{n} a_i$ and the arithmetic mean of set $B$ as $\mu_B = \frac{1}{n} \sum_{i=1}^{n} b_i$. The ...
#
# === Reranked 7 ===
# Score: 0.5417221188545227
# Chunk ID: 9976241_0
# Full Problem: Let $A$, $B$, and $C$ be three consecutive terms of an arithmetic progression. If $D = A \cdot B$, $E = B \cdot C$, and $F = D - E$, then find the value of $F$ in terms of the common difference of the arithmetic progression.
# Full Solution: Let $d$ be the common difference of the arithmetic progression.
#
# Then we have:
# \[ B = A + d \]
# \[ C = B + d = (A + d) + d = A + 2d \]
#
# \[ D = A \cdot B = A(A + d) = A^2 + Ad \]
# \[ E = B \cdot C = (A + d)(A + 2d) = A^2 + 2Ad + Ad + 2d^2 = A^2 + 3Ad + 2d^2 \]
#
# \[ F = D - E = (A^2 + Ad) - (A^2 + 3Ad +  ...
#
# === Reranked 8 ===
# Score: 0.540579080581665
# Chunk ID: 847174_0
# Full Problem: Find the least positive value of $t$ such that
# \[\arccos (\cos \alpha), \ \arccos (\cos 3 \alpha), \ \arccos (\cos 11 \alpha), \ \arccos (\cos t \alpha)\]
# is an arithmetic progression for some $\alpha$ with $0 < \alpha < \pi$.
# Full Solution: ## Step 1: Recall the definition of an arithmetic progression
# An arithmetic progression is a sequence of numbers where the difference between any two consecutive terms is constant.
#
# ## Step 2: Identify the terms in the given sequence
# We are given the sequence $\arccos (\cos \alpha), \ \arccos (\cos  ...
#
# === Reranked 9 ===
# Score: 0.5403550267219543
# Chunk ID: 1867924_0
# Full Problem: Let
# \[\begin{array}{ll}
# \mbox{$A=\{a_1, a_2, \cdots, a_n\}$}&\mbox{ and}\\
# \mbox{$B=\{b_1, b_2, \cdots, b_n\}$}&
# \end{array}\]
# be two different subsets of the set of natural numbers, such that the arithmetic mean of all elements of $B$ is greater tha
# Full Solution: ## Step 1: Define the arithmetic mean, quadratic mean, and the difference between the greatest and least element for both sets.
# For set $A$, the arithmetic mean is $\frac{\sum_{i=1}^{n} a_i}{n}$ and the quadratic mean is $\sqrt{\frac{\sum_{i=1}^{n} a_i^2}{n}}$. Similarly, for set $B$, the arithmetic ...
#
# === Reranked 10 ===
# Score: 0.5402141809463501
# Chunk ID: 8777810_0
# Full Problem: Let $\alpha$ be a fixed real number between $0$ and $\frac{\pi}{2}$. Let $m$ be a positive integer. For any real number $t$, define $f(t)=\arctan (\tan (t\alpha))$. Find the smallest positive real number $k$ such that the sequence
#
# \[f(1), f(2), f(3)
# Full Solution: We have $f(t)=\arctan (\tan (t\alpha))$.
#
# For $0 < \alpha < \frac{\pi}{2}$ and $t$ is a positive integer, we can simplify $f(t)$ as follows:
#
# Since $\tan (t\alpha)$ is periodic with period $\frac{\pi}{\alpha}$, we can find $f(t)$ by taking $t\alpha$ modulo $\frac{\pi}{\alpha}$. That is, we can find  ...
